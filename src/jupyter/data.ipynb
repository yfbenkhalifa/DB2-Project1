# %% [markdown]
# # Data Parsing

# %%
import rdflib
import csv
import pandas as pd
import utilities
dataDir = '../../data'

# %%
# Loading csv file into Json 
csvFile = dataDir + '/EnergyConsumption/EC_Europe.csv'
df = utilities.csvToDataFrame(csvFile)
df.columns = df.iloc[0]
df = df[1:]
display(df)
# Out:
# 0           Country   1965   1966   1967   1968   1969   1970   1971   1972  \
# 1           Austria   0.68   0.71   0.72   0.77   0.80   0.91   0.91   0.94
# 2           Belgium   1.49   1.43   1.50   1.68   1.84   1.94   1.91   2.03
# 3          Bulgaria   0.43   0.46   0.54   0.60   0.67   0.75   0.78   0.81
# 4           Croatia      -      -      -      -      -      -      -      -
# 5            Cyprus   0.02   0.02   0.02   0.02   0.03   0.03   0.03   0.04
# 6    Czech Republic   1.69   1.70   1.67   1.75   1.82   1.90   1.99   2.00
# 7           Denmark   0.60   0.68   0.68   0.72   0.82   0.87   0.83   0.87
# 8           Estonia      -      -      -      -      -      -      -      -
# 9           Finland   0.42   0.47   0.50   0.54   0.59   0.65   0.67   0.71
# 10           France   4.71   4.83   5.14   5.42   5.98   6.49   6.75   7.21
# 11          Germany  10.69  10.72  10.69  11.41  12.31  13.00  13.12  13.57
# ...
